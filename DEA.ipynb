# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.dpi']=200 # highres display
import seaborn as sns

# %%
data = pd.read_csv("Data_World.csv")

# %%
data.head()
# Out:
#      co2_1    co2_2    co2_3    co2_4    co2_5        Beef1        Beef2  \
# 0  192.366  190.930  187.416  190.930  190.930  2528.688000  2417.000000
# 1  401.555  411.032  415.097  411.032  411.032   674.528526   765.779532
# 2   72.835   75.857   80.324   75.857   75.857   204.000000   204.000000
# 3  495.214  478.443  484.588  478.443  478.443  7602.828979  7682.368664
# 4  575.907  564.033  572.834  564.033  564.033   856.407049   900.375632
#
#          Beef3        Beef4        Beef5  ...  trust_1  trust_2   trust_3  \
# 0  2608.530998  2608.316551  2584.341559  ...  0.08484  0.07296  0.059740
# 1   737.115489   730.567972   729.569784  ...  0.35637  0.32331  0.301184
# 2   204.100723   201.228504   200.364477  ...  0.12569  0.12583  0.123718
# 3  7987.269937  8033.591780  8000.274932  ...  0.17521  0.14166  0.111093
# 4   960.562971   961.037544   974.517333  ...  0.32957  0.31329  0.287372
#
#    trust_4  trust_5  health_1  health_2  health_3  health_4  health_5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 40 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   co2_1     36 non-null     float64
#  1   co2_2     36 non-null     float64
#  2   co2_3     36 non-null     float64
#  3   co2_4     36 non-null     float64
#  4   co2_5     36 non-null     float64
#  5   Beef1     36 non-null     float64
#  6   Beef2     36 non-null     float64
#  7   Beef3     36 non-null     float64
#  8   Beef4     36 non-null     float64
#  9   Beef5     36 non-null     float64
#  10  Dep1      36 non-null     float64
#  11  Dep2      36 non-null     float64
#  12  Dep3      36 non-null     float64
#  13  Dep4      36 non-null     float64
#  14  Dep5      36 non-null     float64
#  15  pop_1     36 non-null     float64
#  16  pop_2     36 non-null     float64
#  17  pop_3     36 non-null     float64
#  18  pop_4     36 non-null     float64
# ...

# %%
data.describe()
# Out:
#              co2_1        co2_2        co2_3        co2_4        co2_5  \
# count    36.000000    36.000000    36.000000    36.000000    36.000000
# mean    761.710944   760.865889   771.841139   760.865889   760.865889
# std    1806.939262  1781.835154  1808.236097  1781.835154  1781.835154
# min       6.051000     7.154000     8.015000     7.154000     7.154000
# 25%      79.433500    82.079750    83.127500    82.079750    82.079750
# 50%     221.608000   233.858000   240.647500   233.858000   233.858000
# 75%     498.163500   504.480000   496.194000   504.480000   504.480000
# max    9683.201000  9552.517000  9750.726000  9552.517000  9552.517000
#
#               Beef1         Beef2         Beef3         Beef4         Beef5  \
# count     36.000000     36.000000     36.000000     36.000000     36.000000
# mean    1359.510380   1390.980898   1425.663914   1446.308659   1459.062507
# std     2423.311367   2504.822577   2560.815505   2615.024573   2636.847885
# ...

# %%
plt.hist(data['co2_1'], alpha=0.5, label='2015' , bins=80)
plt.hist(data['co2_2'], alpha=0.5, label='2016', bins=80)
plt.hist(data['co2_3'], alpha=0.5, label='2017', bins=80)
plt.hist(data['co2_4'], alpha=0.5, label='2018', bins=80)
plt.hist(data['co2_5'], alpha=0.5, label='2019', bins=80)
mean=(data['co2_1'].mean(), data['co2_1'].mean())
median1=(data['co2_1'].median(), data['co2_1'].median())
up1 = (np.percentile(data['co2_1'],75), np.percentile(data['co2_1'],75))
low1 = (np.percentile(data['co2_1'],25), np.percentile(data['co2_1'],25))

median2=(data['co2_2'].median(), data['co2_2'].median())
up2 = (np.percentile(data['co2_2'],75), np.percentile(data['co2_2'],75))
low2 = (np.percentile(data['co2_2'],25), np.percentile(data['co2_2'],25))

median3=(data['co2_3'].median(), data['co2_3'].median())
up3 = (np.percentile(data['co2_3'],75), np.percentile(data['co2_3'],75))
low3 = (np.percentile(data['co2_3'],25), np.percentile(data['co2_3'],25))

median4=(data['co2_4'].median(), data['co2_4'].median())
up4 = (np.percentile(data['co2_4'],75), np.percentile(data['co2_4'],75))
low4 = (np.percentile(data['co2_4'],25), np.percentile(data['co2_4'],25))

median5=(data['co2_5'].median(), data['co2_5'].median())
up5 = (np.percentile(data['co2_5'],75), np.percentile(data['co2_5'],75))
low5 = (np.percentile(data['co2_5'],25), np.percentile(data['co2_5'],25))

y=(0,14)

#plt.plot(mean,y,'k-')
plt.plot(median1,y,'b-')
plt.plot(up1,y,'b:')
plt.plot(low1,y,'b:')

plt.plot(median2,y,'k-', color='orange')
plt.plot(up2,y,'k:', color='orange')
plt.plot(low2,y,'k:', color='orange')

plt.plot(median3,y,'g-')
plt.plot(up3,y,'g:')
plt.plot(low3,y,'g:')

plt.plot(median4,y,'r-')
plt.plot(up4,y,'r:')
plt.plot(low4,y,'r:')

plt.plot(median5,y,'k-', color='purple')
plt.plot(up5,y,'k:', color='purple')
plt.plot(low5,y,'k:', color='purple')

plt.xlabel('CO2 emission')
plt.ylabel('Number')
plt.legend(loc='best')

# %%
co2=data['co2_1'].median(), data['co2_2'].median(),data['co2_3'].median(),data['co2_4'].median(),data['co2_5'].median()

# %%
co2
# Out:
# (221.608, 233.858, 240.6475, 233.858, 233.858)

# %%
np.mean(co2)
# Out:
# 232.76590000000002

# %%
plt.hist(data['co2_1'], alpha=0.5, label='2015' , bins=20)
#plt.hist(data['co2_2'], alpha=0.5, label='2016', bins=20)
#plt.hist(data['co2_3'], alpha=0.5, label='2017', bins=20)
#plt.hist(data['co2_4'], alpha=0.5, label='2018', bins=20)
plt.hist(data['co2_5'], alpha=0.5, label='2019', bins=20)
mean=(data['co2_1'].mean(), data['co2_1'].mean())
median=(data['co2_1'].median(), data['co2_1'].median())
up = (np.percentile(data['co2_1'],75), np.percentile(data['co2_1'],75))
low = (np.percentile(data['co2_1'],25), np.percentile(data['co2_1'],25))
y=(0,35)

#plt.plot(mean,y,'k-')
plt.plot(median,y,'k-')
plt.plot(up,y,'k:')
plt.plot(low,y,'k:')

plt.xlabel('CO2')
plt.ylabel('Number')
plt.legend(loc='best')

# %%
plt.hist(data['Beef1'], alpha=0.5, label='2015')
#plt.hist(data['Beef2'], alpha=0.5, label='2016')
#plt.hist(data['Beef3'], alpha=0.5, label='2017')
#plt.hist(data['Beef4'], alpha=0.5, label='2018')
plt.hist(data['Beef5'], alpha=0.5, label='2019')


mean=(data['Beef1'].mean(), data['Beef1'].mean())
median1=(data['Beef1'].median(), data['Beef1'].median())
up1 = (np.percentile(data['Beef1'],75), np.percentile(data['Beef1'],75))
low1 = (np.percentile(data['Beef1'],25), np.percentile(data['Beef1'],25))

median2=(data['Beef2'].median(), data['Beef2'].median())
up2 = (np.percentile(data['Beef2'],75), np.percentile(data['Beef2'],75))
low2 = (np.percentile(data['Beef2'],25), np.percentile(data['Beef2'],25))

median3=(data['Beef3'].median(), data['Beef3'].median())
up3 = (np.percentile(data['Beef3'],75), np.percentile(data['Beef3'],75))
low3 = (np.percentile(data['Beef3'],25), np.percentile(data['Beef3'],25))

median4=(data['Beef4'].median(), data['Beef4'].median())
up4 = (np.percentile(data['Beef4'],75), np.percentile(data['Beef4'],75))
low4 = (np.percentile(data['Beef4'],25), np.percentile(data['Beef4'],25))

median5=(data['Beef5'].median(), data['Beef5'].median())
up5 = (np.percentile(data['Beef5'],75), np.percentile(data['Beef5'],75))
low5 = (np.percentile(data['Beef5'],25), np.percentile(data['Beef5'],25))

y=(0,26)

#plt.plot(mean,y,'k-')
plt.plot(median1,y,'b-')
plt.plot(up1,y,'b:')
plt.plot(low1,y,'b:')

plt.plot(median2,y,'k-', color='orange')
plt.plot(up2,y,'k:', color='orange')
plt.plot(low2,y,'k:', color='orange')

plt.plot(median3,y,'g-')
plt.plot(up3,y,'g:')
plt.plot(low3,y,'g:')

plt.plot(median4,y,'r-')
plt.plot(up4,y,'r:')
plt.plot(low4,y,'r:')

plt.plot(median5,y,'k-', color='purple')
plt.plot(up5,y,'k:', color='purple')
plt.plot(low5,y,'k:', color='purple')

plt.xlabel('Beef consumption (Thousand tonnes)')
plt.ylabel('Number')
plt.legend(loc='best')

# %%
data['Beef1'].median(),data['Beef2'].median(),data['Beef3'].median(),data['Beef4'].median(),data['Beef5'].median()
# Out:
# (433.5, 450.0, 461.677643814325, 464.964878292978, 470.31138468271354)

# %%
print(((data['Beef5'].median()-data['Beef1'].median())/data['Beef5'].median())*100)
# Out:
# 7.827023942349945

# %%
plt.hist(data['Dep1'], alpha=0.5, label='2015', bins=500)
plt.hist(data['Dep2'], alpha=0.5, label='2016', bins=1000)
plt.hist(data['Dep3'], alpha=0.5, label='2017', bins=1000)
plt.hist(data['Dep4'], alpha=0.5, label='2018', bins=1000)
plt.hist(data['Dep5'], alpha=0.5, label='2019', bins=500)


mean=(data['Dep1'].mean(), data['Dep1'].mean())
median1=(data['Dep1'].median(), data['Dep1'].median())
up1 = (np.percentile(data['Dep1'],75), np.percentile(data['Dep1'],75))
low1 = (np.percentile(data['Dep1'],25), np.percentile(data['Dep1'],25))

median2=(data['Dep2'].median(), data['Dep2'].median())
up2 = (np.percentile(data['Dep2'],75), np.percentile(data['Dep2'],75))
low2 = (np.percentile(data['Dep2'],25), np.percentile(data['Dep2'],25))

median3=(data['Dep3'].median(), data['Dep3'].median())
up3 = (np.percentile(data['Dep3'],75), np.percentile(data['Dep3'],75))
low3 = (np.percentile(data['Dep3'],25), np.percentile(data['Dep3'],25))

median4=(data['Dep4'].median(), data['Dep4'].median())
up4 = (np.percentile(data['Dep4'],75), np.percentile(data['Dep4'],75))
low4 = (np.percentile(data['Dep4'],25), np.percentile(data['Dep4'],25))

median5=(data['Dep5'].median(), data['Dep5'].median())
up5 = (np.percentile(data['Dep5'],75), np.percentile(data['Dep5'],75))
low5 = (np.percentile(data['Dep5'],25), np.percentile(data['Dep5'],25))

y=(0,4.5)

#plt.plot(mean,y,'k-')
plt.plot(median1,y,'b-')
plt.plot(up1,y,'b:')
plt.plot(low1,y,'b:')

plt.plot(median2,y,'k-', color='orange')
plt.plot(up2,y,'k:', color='orange')
plt.plot(low2,y,'k:', color='orange')

plt.plot(median3,y,'g-')
plt.plot(up3,y,'g:')
plt.plot(low3,y,'g:')

plt.plot(median4,y,'r-')
plt.plot(up4,y,'r:')
plt.plot(low4,y,'r:')

plt.plot(median5,y,'k-', color='purple')
plt.plot(up5,y,'k:', color='purple')
plt.plot(low5,y,'k:', color='purple')


plt.xscale('log')
plt.xlabel('Number of Flights')
plt.ylabel('Number')
plt.legend(loc='best')

# %%
data['Dep1'].median(), data['Dep2'].median(),data['Dep3'].median(),data['Dep4'].median(),data['Dep5'].median()
# Out:
# (207475.5, 221197.5, 220917.544, 226969.0, 234779.0)

# %%
print(((data['Dep5'].median()-data['Dep1'].median())/data['Dep5'].median())*100)
# Out:
# 11.629447267430223

# %%
plt.hist(data['pop_1'], alpha=0.5, label='2015', bins=500)
#plt.hist(data['pop_2'], alpha=0.5, label='2016', bins=500)
#plt.hist(data['pop_3'], alpha=0.5, label='2017', bins=500)
#plt.hist(data['pop_4'], alpha=0.5, label='2018', bins=500)
plt.hist(data['pop_5'], alpha=0.5, label='2019', bins=500)

mean=(data['pop_1'].mean(), data['pop_1'].mean())
median1=(data['pop_1'].median(), data['pop_1'].median())
up1 = (np.percentile(data['pop_1'],75), np.percentile(data['pop_1'],75))
low1 = (np.percentile(data['pop_1'],25), np.percentile(data['pop_1'],25))

median2=(data['pop_2'].median(), data['pop_2'].median())
up2 = (np.percentile(data['pop_2'],75), np.percentile(data['pop_2'],75))
low2 = (np.percentile(data['pop_2'],25), np.percentile(data['pop_2'],25))

median3=(data['pop_3'].median(), data['pop_3'].median())
up3 = (np.percentile(data['pop_3'],75), np.percentile(data['pop_3'],75))
low3 = (np.percentile(data['pop_3'],25), np.percentile(data['pop_3'],25))

median4=(data['pop_4'].median(), data['pop_4'].median())
up4 = (np.percentile(data['pop_4'],75), np.percentile(data['pop_4'],75))
low4 = (np.percentile(data['pop_4'],25), np.percentile(data['pop_4'],25))

median5=(data['pop_5'].median(), data['pop_5'].median())
up5 = (np.percentile(data['pop_5'],75), np.percentile(data['pop_5'],75))
low5 = (np.percentile(data['pop_5'],25), np.percentile(data['pop_5'],25))

y=(0,3.5)

#plt.plot(mean,y,'k-')
plt.plot(median1,y,'b-')
plt.plot(up1,y,'b:')
plt.plot(low1,y,'b:')

plt.plot(median2,y,'k-', color='orange')
plt.plot(up2,y,'k:', color='orange')
plt.plot(low2,y,'k:', color='orange')

plt.plot(median3,y,'g-')
plt.plot(up3,y,'g:')
plt.plot(low3,y,'g:')

plt.plot(median4,y,'r-')
plt.plot(up4,y,'r:')
plt.plot(low4,y,'r:')

plt.plot(median5,y,'k-', color='purple')
plt.plot(up5,y,'k:', color='purple')
plt.plot(low5,y,'k:', color='purple')


plt.xlabel('Global Population')
plt.ylabel('Number')
plt.legend(loc='best')
plt.xscale('log')

# %%
data['pop_1'].median(),data['pop_2'].median(),data['pop_3'].median(),data['pop_4'].median(),data['pop_5'].median()
# Out:
# (62050500.0, 62589500.0, 63110000.0, 63610500.0, 64092000.0)

# %%
plt.hist(data['trust_1'], alpha=0.5, label='2015')
#plt.hist(data['trust_2'], alpha=0.5, label='2016')
#plt.hist(data['trust_3'], alpha=0.5, label='2017')
#plt.hist(data['trust_4'], alpha=0.5, label='2018')
plt.hist(data['trust_5'], alpha=0.5, label='2019')
ft='trust_1'
mean=(data[ft].mean(), data[ft].mean())
median1=(data[ft].median(), data[ft].median())
up1 = (np.percentile(data[ft],75), np.percentile(data[ft],75))
low1 = (np.percentile(data[ft],25), np.percentile(data[ft],25))
print(data[ft].median())
ft='trust_2'
median2=(data[ft].median(), data[ft].median())
up2 = (np.percentile(data[ft],75), np.percentile(data[ft],75))
low2 = (np.percentile(data[ft],25), np.percentile(data[ft],25))
print(data[ft].median())
ft='trust_3'
median3=(data[ft].median(), data[ft].median())
up3 = (np.percentile(data[ft],75), np.percentile(data[ft],75))
low3 = (np.percentile(data[ft],25), np.percentile(data[ft],25))
print(data[ft].median())
ft='trust_4'
median4=(data[ft].median(), data[ft].median())
up4 = (np.percentile(data[ft],75), np.percentile(data[ft],75))
low4 = (np.percentile(data[ft],25), np.percentile(data[ft],25))
print(data[ft].median())
ft='trust_5'
median5=(data[ft].median(), data[ft].median())
up5 = (np.percentile(data[ft],75), np.percentile(data[ft],75))
low5 = (np.percentile(data[ft],25), np.percentile(data[ft],25))
print(data[ft].median())

y=(0,11)

#plt.plot(mean,y,'k-')
plt.plot(median1,y,'b-')
plt.plot(up1,y,'b:')
plt.plot(low1,y,'b:')

plt.plot(median2,y,'k-', color='orange')
plt.plot(up2,y,'k:', color='orange')
plt.plot(low2,y,'k:', color='orange')

plt.plot(median3,y,'g-')
plt.plot(up3,y,'g:')
plt.plot(low3,y,'g:')

plt.plot(median4,y,'r-')
plt.plot(up4,y,'r:')
plt.plot(low4,y,'r:')

plt.plot(median5,y,'k-', color='purple')
plt.plot(up5,y,'k:', color='purple')
plt.plot(low5,y,'k:', color='purple')



plt.xlabel('Trust')
plt.ylabel('Number')
plt.legend(loc='best')
# Out:
# 0.096625
# 0.107625
# 0.09164649999999999
# 0.1
# 0.08549999999999999

# %%
plt.hist(data['hap_1'], alpha=0.5, label='2015')
plt.hist(data['hap_2'], alpha=0.5, label='2016')
plt.hist(data['hap_3'], alpha=0.5, label='2017')
plt.hist(data['hap_4'], alpha=0.5, label='2018')
plt.hist(data['hap_5'], alpha=0.5, label='2019')

median1=(data['hap_1'].median(), data['hap_1'].median())
up1 = (np.percentile(data['hap_1'],75), np.percentile(data['hap_1'],75))
low1 = (np.percentile(data['hap_1'],25), np.percentile(data['hap_1'],25))

median2=(data['hap_2'].median(), data['hap_2'].median())
up2 = (np.percentile(data['hap_2'],75), np.percentile(data['hap_2'],75))
low2 = (np.percentile(data['hap_2'],25), np.percentile(data['hap_2'],25))

median3=(data['hap_3'].median(), data['hap_3'].median())
up3 = (np.percentile(data['hap_3'],75), np.percentile(data['hap_3'],75))
low3 = (np.percentile(data['hap_3'],25), np.percentile(data['hap_3'],25))

median4=(data['hap_4'].median(), data['hap_4'].median())
up4 = (np.percentile(data['hap_4'],75), np.percentile(data['hap_4'],75))
low4 = (np.percentile(data['hap_4'],25), np.percentile(data['hap_4'],25))

median5=(data['hap_5'].median(), data['hap_5'].median())
up5 = (np.percentile(data['hap_5'],75), np.percentile(data['hap_5'],75))
low5 = (np.percentile(data['hap_5'],25), np.percentile(data['hap_5'],25))

y=(0,9)

#plt.plot(mean,y,'k-')
plt.plot(median1,y,'b-')
plt.plot(up1,y,'b:')
plt.plot(low1,y,'b:')

plt.plot(median2,y,'k-', color='orange')
plt.plot(up2,y,'k:', color='orange')
plt.plot(low2,y,'k:', color='orange')

plt.plot(median3,y,'g-')
plt.plot(up3,y,'g:')
plt.plot(low3,y,'g:')

plt.plot(median4,y,'r-')
plt.plot(up4,y,'r:')
plt.plot(low4,y,'r:')

plt.plot(median5,y,'k-', color='purple')
plt.plot(up5,y,'k:', color='purple')
plt.plot(low5,y,'k:', color='purple')




#plt.xscale('log')
plt.xlabel('Happiness')
plt.ylabel('Number')
plt.legend(loc='best')

# %%
data['hap_1'].median(), data['hap_2'].median(),data['hap_3'].median(),data['hap_4'].median(),data['hap_5'].median()
# Out:
# (5.743, 5.7995, 5.7669999999999995, 5.672000000000001, 5.6395)

# %%
plt.hist(data['eco_1'], alpha=0.5, label='2015')
plt.hist(data['eco_2'], alpha=0.5, label='2016')
plt.hist(data['eco_3'], alpha=0.5, label='2017')
plt.hist(data['eco_4'], alpha=0.5, label='2018')
plt.hist(data['eco_5'], alpha=0.5, label='2019')


median1=(data['eco_1'].median(), data['eco_1'].median())
up1 = (np.percentile(data['eco_1'],75), np.percentile(data['eco_1'],75))
low1 = (np.percentile(data['eco_1'],25), np.percentile(data['eco_1'],25))

median2=(data['eco_2'].median(), data['eco_2'].median())
up2 = (np.percentile(data['eco_2'],75), np.percentile(data['eco_2'],75))
low2 = (np.percentile(data['eco_2'],25), np.percentile(data['eco_2'],25))

median3=(data['eco_3'].median(), data['eco_3'].median())
up3 = (np.percentile(data['eco_3'],75), np.percentile(data['eco_3'],75))
low3 = (np.percentile(data['eco_3'],25), np.percentile(data['eco_3'],25))

median4=(data['eco_4'].median(), data['eco_4'].median())
up4 = (np.percentile(data['eco_4'],75), np.percentile(data['eco_4'],75))
low4 = (np.percentile(data['eco_4'],25), np.percentile(data['eco_4'],25))

median5=(data['eco_5'].median(), data['eco_5'].median())
up5 = (np.percentile(data['eco_5'],75), np.percentile(data['eco_5'],75))
low5 = (np.percentile(data['eco_5'],25), np.percentile(data['eco_5'],25))

y=(0,9)

#plt.plot(mean,y,'k-')
plt.plot(median1,y,'b-')
plt.plot(up1,y,'b:')
plt.plot(low1,y,'b:')

plt.plot(median2,y,'k-', color='orange')
plt.plot(up2,y,'k:', color='orange')
plt.plot(low2,y,'k:', color='orange')

plt.plot(median3,y,'g-')
plt.plot(up3,y,'g:')
plt.plot(low3,y,'g:')

plt.plot(median4,y,'r-')
plt.plot(up4,y,'r:')
plt.plot(low4,y,'r:')

plt.plot(median5,y,'k-', color='purple')
plt.plot(up5,y,'k:', color='purple')
plt.plot(low5,y,'k:', color='purple')


#plt.xscale('log')
plt.xlabel('Economy')
plt.ylabel('Number')
plt.legend(loc='best')

# %%
data['eco_1'].median(), data['eco_2'].median(),data['eco_3'].median(),data['eco_4'].median(),data['eco_5'].median()
# Out:
# (0.953095, 1.0701, 1.0996085, 0.9875, 1.0030000000000001)

# %%
((data['eco_5'].median()-data['eco_1'].median())/data['eco_5'].median())*100
# Out:
# 4.975573280159529

# %%
plt.hist(data['health_1'], alpha=0.5, label='2015')
plt.hist(data['health_2'], alpha=0.5, label='2016')
plt.hist(data['health_3'], alpha=0.5, label='2017')
plt.hist(data['health_4'], alpha=0.5, label='2018')
plt.hist(data['health_5'], alpha=0.5, label='2019')

median1=(data['health_1'].median(), data['health_1'].median())
up1 = (np.percentile(data['health_1'],75), np.percentile(data['health_1'],75))
low1 = (np.percentile(data['health_1'],25), np.percentile(data['health_1'],25))

median2=(data['health_2'].median(), data['health_2'].median())
up2 = (np.percentile(data['health_2'],75), np.percentile(data['health_2'],75))
low2 = (np.percentile(data['health_2'],25), np.percentile(data['health_2'],25))

median3=(data['health_3'].median(), data['health_3'].median())
up3 = (np.percentile(data['health_3'],75), np.percentile(data['health_3'],75))
low3 = (np.percentile(data['health_3'],25), np.percentile(data['health_3'],25))

median4=(data['health_4'].median(), data['health_4'].median())
up4 = (np.percentile(data['health_4'],75), np.percentile(data['health_4'],75))
low4 = (np.percentile(data['health_4'],25), np.percentile(data['health_4'],25))

median5=(data['health_5'].median(), data['health_5'].median())
up5 = (np.percentile(data['health_5'],75), np.percentile(data['health_5'],75))
low5 = (np.percentile(data['health_5'],25), np.percentile(data['health_5'],25))

y=(0,13)

#plt.plot(mean,y,'k-')
plt.plot(median1,y,'b-')
plt.plot(up1,y,'b:')
plt.plot(low1,y,'b:')

plt.plot(median2,y,'k-', color='orange')
plt.plot(up2,y,'k:', color='orange')
plt.plot(low2,y,'k:', color='orange')

plt.plot(median3,y,'g-')
plt.plot(up3,y,'g:')
plt.plot(low3,y,'g:')

plt.plot(median4,y,'r-')
plt.plot(up4,y,'r:')
plt.plot(low4,y,'r:')

plt.plot(median5,y,'k-', color='purple')
plt.plot(up5,y,'k:', color='purple')
plt.plot(low5,y,'k:', color='purple')

#plt.xscale('log')
plt.xlabel('Health')
plt.ylabel('Number')
plt.legend(loc='best')

# %%
data['health_1'].median(), data['health_2'].median(),data['health_3'].median(),data['health_4'].median(),data['health_5'].median()
# Out:
# (0.697535, 0.6160950000000001, 0.6170685, 0.6715, 0.7935000000000001)

# %%
((data['health_5'].median()-data['health_1'].median())/data['health_5'].median())*100
# Out:
# 12.09388783868936

# %%
corr_All = data.corr()
ax = sns.heatmap(
    corr_All, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
)
# Out:
# [Text(0.5, 0, 'co2_1'),
#  Text(2.5, 0, 'co2_3'),
#  Text(4.5, 0, 'co2_5'),
#  Text(6.5, 0, 'Beef2'),
#  Text(8.5, 0, 'Beef4'),
#  Text(10.5, 0, 'Dep1'),
#  Text(12.5, 0, 'Dep3'),
#  Text(14.5, 0, 'Dep5'),
#  Text(16.5, 0, 'pop_2'),
#  Text(18.5, 0, 'pop_4'),
#  Text(20.5, 0, 'hap_1'),
#  Text(22.5, 0, 'hap_3'),
#  Text(24.5, 0, 'hap_5'),
#  Text(26.5, 0, 'eco_2'),
#  Text(28.5, 0, 'eco_4'),
#  Text(30.5, 0, 'trust_1'),
#  Text(32.5, 0, 'trust_3'),
#  Text(34.5, 0, 'trust_5'),
#  Text(36.5, 0, 'health_2'),
#  Text(38.5, 0, 'health_4')]

# %%
cov_All = data.cov()
ax = sns.heatmap(
    cov_All, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
)
# Out:
# [Text(0.5, 0, 'co2_1'),
#  Text(2.5, 0, 'co2_3'),
#  Text(4.5, 0, 'co2_5'),
#  Text(6.5, 0, 'Beef2'),
#  Text(8.5, 0, 'Beef4'),
#  Text(10.5, 0, 'Dep1'),
#  Text(12.5, 0, 'Dep3'),
#  Text(14.5, 0, 'Dep5'),
#  Text(16.5, 0, 'pop_2'),
#  Text(18.5, 0, 'pop_4'),
#  Text(20.5, 0, 'hap_1'),
#  Text(22.5, 0, 'hap_3'),
#  Text(24.5, 0, 'hap_5'),
#  Text(26.5, 0, 'eco_2'),
#  Text(28.5, 0, 'eco_4'),
#  Text(30.5, 0, 'trust_1'),
#  Text(32.5, 0, 'trust_3'),
#  Text(34.5, 0, 'trust_5'),
#  Text(36.5, 0, 'health_2'),
#  Text(38.5, 0, 'health_4')]

# %%
plt.scatter(data['Dep1'],data['co2_1'], label='2015')
plt.scatter(data['Dep3'],data['co2_3'], label='2017')
plt.scatter(data['Dep5'],data['co2_5'], label='2019')
plt.xscale('log')
plt.xlabel('Flights per country')
plt.ylabel('CO2 per country')
plt.legend(loc='best')

# %%
plt.scatter(data['pop_1'],data['co2_1'], label='2015')
plt.scatter(data['pop_3'],data['co2_3'], label='2017')
plt.scatter(data['pop_5'],data['co2_5'], label='2019')
plt.xscale('log')
plt.ylabel('CO2 per country')
plt.xlabel('Population per country')
plt.legend(loc='best')

# %%
#Not Correlation
plt.scatter(data['Beef1'],data['co2_1'], label='2015')
plt.scatter(data['Beef2'],data['co2_2'], label='2016')
plt.scatter(data['Beef3'],data['co2_3'], label='2017')
plt.scatter(data['Beef4'],data['co2_4'], label='2018')
plt.scatter(data['Beef5'],data['co2_5'], label='2019')

plt.yscale('log')
plt.ylabel('CO2 per country')
plt.xlabel('Beef consumption per country')
plt.legend(loc='best')

# %%
plt.scatter(data['hap_1'],data['co2_1'], label='2015')
plt.scatter(data['hap_2'],data['co2_2'], label='2016')
plt.scatter(data['hap_3'],data['co2_3'], label='2017')
plt.scatter(data['hap_4'],data['co2_4'], label='2018')
plt.scatter(data['hap_5'],data['co2_5'], label='2019')
plt.ylabel('CO2 per country')
plt.xlabel('Happiness per country')
#plt.xscale('log')
plt.legend(loc='best')

# %%
plt.scatter(data['eco_1'],data['co2_1'], label='2015')
plt.scatter(data['eco_2'],data['co2_2'], label='2016')
plt.scatter(data['eco_3'],data['co2_3'], label='2017')
plt.scatter(data['eco_4'],data['co2_4'], label='2018')
plt.scatter(data['eco_5'],data['co2_5'], label='2019')
plt.ylabel('CO2 per country')
plt.xlabel('Economy per country')
#plt.xscale('log')
plt.legend(loc='best')

# %%
plt.scatter(data['trust_1'],data['co2_1'], label='2015')
plt.scatter(data['trust_2'],data['co2_2'], label='2016')
plt.scatter(data['trust_3'],data['co2_3'], label='2017')
plt.scatter(data['trust_4'],data['co2_4'], label='2018')
plt.scatter(data['trust_5'],data['co2_5'], label='2019')
plt.ylabel('CO2 per country')
plt.xlabel('Trust per country')
#plt.xscale('log')
plt.legend(loc='best')

# %%
plt.scatter(data['health_1'],data['co2_1'], label='2015')
plt.scatter(data['health_2'],data['co2_2'], label='2016')
plt.scatter(data['health_3'],data['co2_3'], label='2017')
plt.scatter(data['health_4'],data['co2_4'], label='2018')
plt.scatter(data['health_5'],data['co2_5'], label='2019')
plt.ylabel('CO2 per country')
plt.xlabel('Health per country')
#plt.xscale('log')
plt.legend(loc='best')

# %%
plt.scatter(data['health_1'],data['Dep1'], label='2015')
plt.scatter(data['health_2'],data['Dep2'], label='2016')
plt.scatter(data['health_3'],data['Dep3'], label='2017')
plt.scatter(data['health_4'],data['Dep4'], label='2018')
plt.scatter(data['health_5'],data['Dep5'], label='2019')
plt.ylabel('Flights per country')
plt.xlabel('Health per country')
plt.yscale('log')
plt.legend(loc='best')

# %%
plt.scatter(data['trust_1'],data['Dep1'], label='2015')
plt.scatter(data['trust_2'],data['Dep2'], label='2016')
plt.scatter(data['trust_3'],data['Dep3'], label='2017')
plt.scatter(data['trust_4'],data['Dep4'], label='2018')
plt.scatter(data['trust_5'],data['Dep5'], label='2019')
plt.ylabel('Flights per country')
plt.xlabel('Trust per country')
plt.yscale('log')
plt.legend(loc='best')

# %%
plt.scatter(data['hap_1'],data['Dep1'], label='2015')
plt.scatter(data['hap_2'],data['Dep2'], label='2016')
plt.scatter(data['hap_3'],data['Dep3'], label='2017')
plt.scatter(data['hap_4'],data['Dep4'], label='2018')
plt.scatter(data['hap_5'],data['Dep5'], label='2019')
plt.ylabel('Flights per country')
plt.xlabel('Happiness per country')
plt.yscale('log')
plt.legend(loc='best')

# %%
plt.scatter(data['eco_1'],data['Dep1'], label='2015')
plt.scatter(data['eco_2'],data['Dep2'], label='2016')
plt.scatter(data['eco_3'],data['Dep3'], label='2017')
plt.scatter(data['eco_4'],data['Dep4'], label='2018')
plt.scatter(data['eco_5'],data['Dep5'], label='2019')
plt.ylabel('Flights per country')
plt.xlabel('Economy per country')
plt.yscale('log')
plt.legend(loc='best')

# %%
plt.scatter(data['eco_1'],data['pop_1'], label='2015')
plt.scatter(data['eco_2'],data['pop_2'], label='2016')
plt.scatter(data['eco_3'],data['pop_3'], label='2017')
plt.scatter(data['eco_4'],data['pop_4'], label='2018')
plt.scatter(data['eco_5'],data['pop_5'], label='2019')
plt.ylabel('Population per country')
plt.xlabel('Economy per country')
plt.yscale('log')
plt.legend(loc='best')

# %%
plt.scatter(data['hap_1'],data['pop_1'], label='2015')
plt.scatter(data['hap_2'],data['pop_2'], label='2016')
plt.scatter(data['hap_3'],data['pop_3'], label='2017')
plt.scatter(data['hap_4'],data['pop_4'], label='2018')
plt.scatter(data['hap_5'],data['pop_5'], label='2019')
plt.ylabel('Population per country')
plt.xlabel('Happiness per country')
plt.yscale('log')
plt.legend(loc='best')

# %%
plt.scatter(data['trust_1'],data['pop_1'], label='2015')
plt.scatter(data['trust_2'],data['pop_2'], label='2016')
plt.scatter(data['trust_3'],data['pop_3'], label='2017')
plt.scatter(data['trust_4'],data['pop_4'], label='2018')
plt.scatter(data['trust_5'],data['pop_5'], label='2019')
plt.ylabel('Population per country')
plt.xlabel('Trust per country')
plt.yscale('log')
plt.legend(loc='upper right')

# %%
plt.scatter(data['health_1'],data['pop_1'], label='2015')
plt.scatter(data['health_2'],data['pop_2'], label='2016')
plt.scatter(data['health_3'],data['pop_3'], label='2017')
plt.scatter(data['health_4'],data['pop_4'], label='2018')
plt.scatter(data['health_5'],data['pop_5'], label='2019')
plt.ylabel('Population per country')
plt.xlabel('Health per country')
plt.yscale('log')
plt.legend(loc='upper right')

# %%
plt.scatter(data['health_1'],data['Beef1'], label='2015')
plt.scatter(data['health_2'],data['Beef2'], label='2016')
plt.scatter(data['health_3'],data['Beef3'], label='2017')
plt.scatter(data['health_4'],data['Beef4'], label='2018')
plt.scatter(data['health_5'],data['Beef5'], label='2019')
plt.ylabel('Beef consumption per country')
plt.xlabel('Health per country')
plt.yscale('log')
plt.legend(loc='upper right')

# %%
plt.scatter(data['trust_1'],data['Beef1'], label='2015')
plt.scatter(data['trust_2'],data['Beef2'], label='2016')
plt.scatter(data['trust_3'],data['Beef3'], label='2017')
plt.scatter(data['trust_4'],data['Beef4'], label='2018')
plt.scatter(data['trust_5'],data['Beef5'], label='2019')
plt.ylabel('Beef consumption per country')
plt.xlabel('Trust per country')
plt.yscale('log')
plt.legend(loc='upper right')

# %%
plt.scatter(data['hap_1'],data['Beef1'], label='2015')
plt.scatter(data['hap_2'],data['Beef2'], label='2016')
plt.scatter(data['hap_3'],data['Beef3'], label='2017')
plt.scatter(data['hap_4'],data['Beef4'], label='2018')
plt.scatter(data['hap_5'],data['Beef5'], label='2019')
plt.ylabel('Beef consumption per country')
plt.xlabel('Happiness per country')
plt.yscale('log')
plt.legend(loc='upper right')

# %%
plt.scatter(data['eco_1'],data['Beef1'], label='2015')
plt.scatter(data['eco_2'],data['Beef2'], label='2016')
plt.scatter(data['eco_3'],data['Beef3'], label='2017')
plt.scatter(data['eco_4'],data['Beef4'], label='2018')
plt.scatter(data['eco_5'],data['Beef5'], label='2019')
plt.ylabel('Beef consumption per country')
plt.xlabel('Happiness per country')
plt.yscale('log')
plt.legend(loc='upper right')

# %%
plt.scatter(data['eco_1'],data['health_1'], label='2015')
plt.scatter(data['eco_2'],data['health_2'], label='2016')
plt.scatter(data['eco_3'],data['health_3'], label='2017')
plt.scatter(data['eco_4'],data['health_4'], label='2018')
plt.scatter(data['eco_5'],data['health_5'], label='2019')
plt.ylabel('Health per country')
plt.xlabel('Economy per country')
plt.yscale('log')
plt.legend(loc='best')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 40 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   co2_1     36 non-null     float64
#  1   co2_2     36 non-null     float64
#  2   co2_3     36 non-null     float64
#  3   co2_4     36 non-null     float64
#  4   co2_5     36 non-null     float64
#  5   Beef1     36 non-null     float64
#  6   Beef2     36 non-null     float64
#  7   Beef3     36 non-null     float64
#  8   Beef4     36 non-null     float64
#  9   Beef5     36 non-null     float64
#  10  Dep1      36 non-null     float64
#  11  Dep2      36 non-null     float64
#  12  Dep3      36 non-null     float64
#  13  Dep4      36 non-null     float64
#  14  Dep5      36 non-null     float64
#  15  pop_1     36 non-null     float64
#  16  pop_2     36 non-null     float64
#  17  pop_3     36 non-null     float64
#  18  pop_4     36 non-null     float64
# ...

# %%
data.head()
# Out:
#      co2_1    co2_2    co2_3    co2_4    co2_5        Beef1        Beef2  \
# 0  192.366  190.930  187.416  190.930  190.930  2528.688000  2417.000000
# 1  401.555  411.032  415.097  411.032  411.032   674.528526   765.779532
# 2   72.835   75.857   80.324   75.857   75.857   204.000000   204.000000
# 3  495.214  478.443  484.588  478.443  478.443  7602.828979  7682.368664
# 4  575.907  564.033  572.834  564.033  564.033   856.407049   900.375632
#
#          Beef3        Beef4        Beef5  ...  trust_1  trust_2   trust_3  \
# 0  2608.530998  2608.316551  2584.341559  ...  0.08484  0.07296  0.059740
# 1   737.115489   730.567972   729.569784  ...  0.35637  0.32331  0.301184
# 2   204.100723   201.228504   200.364477  ...  0.12569  0.12583  0.123718
# 3  7987.269937  8033.591780  8000.274932  ...  0.17521  0.14166  0.111093
# 4   960.562971   961.037544   974.517333  ...  0.32957  0.31329  0.287372
#
#    trust_4  trust_5  health_1  health_2  health_3  health_4  health_5
# ...

# %%
plt.hist(data['co2_1'], alpha=0.5, label='2015' , bins=20)
#plt.hist(data['co2_2'], alpha=0.5, label='2016', bins=20)
#plt.hist(data['co2_3'], alpha=0.5, label='2017', bins=20)
#plt.hist(data['co2_4'], alpha=0.5, label='2018', bins=20)
plt.hist(data['co2_5'], alpha=0.5, label='2019', bins=20)
mean=(data['co2_1'].mean(), data['co2_1'].mean())
median=(data['co2_1'].median(), data['co2_1'].median())
up = (np.percentile(data['co2_1'],75), np.percentile(data['co2_1'],75))
low = (np.percentile(data['co2_1'],25), np.percentile(data['co2_1'],25))
y=(0,35)

#plt.plot(mean,y,'k-')
plt.plot(median,y,'k-')
plt.plot(up,y,'k:')
plt.plot(low,y,'k:')

plt.xlabel('CO2')
plt.ylabel('Number')
plt.legend(loc='best')

# %%
print(data['co2_5'].median(), np.percentile(data['co2_5'],25), np.percentile(data['co2_5'],75) )
# Out:
# 233.858 82.07974999999999 504.48

# %%
pollutes = data[data['co2_5']>504]

# %%
pollutes.head()
# Out:
#        co2_1     co2_2     co2_3     co2_4     co2_5        Beef1  \
# 4    575.907   564.033   572.834   564.033   564.033   856.407049
# 7   9683.201  9552.517  9750.726  9552.517  9552.517  7564.012600
# 13   507.012   568.194   531.012   568.194   568.194   671.000000
# 14  2253.429  2392.360  2456.848  2392.360  2392.360   952.000061
# 15   640.811   648.061   724.578   648.061   648.061   348.000000
#
#           Beef2        Beef3        Beef4        Beef5  ...  trust_1  trust_2  \
# 4    900.375632   960.562971   961.037544   974.517333  ...  0.32957  0.31329
# 7   7900.211895  8065.707088  8274.688444  8517.757172  ...  0.02781  0.02745
# 13   685.000000   703.716227   722.289530   741.288517  ...  0.00000  0.00322
# 14   984.999939  1009.385598  1021.431145  1026.711652  ...  0.08492  0.08722
# 15   381.000000   387.291134   390.708630   392.323650  ...  0.05863  0.05570
#
#      trust_3  trust_4  trust_5  health_1  health_2  health_3  health_4  \
# ...

# %%
pollutes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 4 to 33
# Data columns (total 40 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   co2_1     9 non-null      float64
#  1   co2_2     9 non-null      float64
#  2   co2_3     9 non-null      float64
#  3   co2_4     9 non-null      float64
#  4   co2_5     9 non-null      float64
#  5   Beef1     9 non-null      float64
#  6   Beef2     9 non-null      float64
#  7   Beef3     9 non-null      float64
#  8   Beef4     9 non-null      float64
#  9   Beef5     9 non-null      float64
#  10  Dep1      9 non-null      float64
#  11  Dep2      9 non-null      float64
#  12  Dep3      9 non-null      float64
#  13  Dep4      9 non-null      float64
#  14  Dep5      9 non-null      float64
#  15  pop_1     9 non-null      float64
#  16  pop_2     9 non-null      float64
#  17  pop_3     9 non-null      float64
#  18  pop_4     9 non-null      float64
# ...

# %%
no_pollutes = data[data['co2_5']<504]

# %%
pollutes=pollutes.drop(['co2_1','co2_2','co2_3','co2_4','Beef1','Beef2',
               'Beef3','Beef4','Dep1','Dep2','Dep3','Dep4','pop_1',
               'pop_2','pop_3','pop_4','hap_1','hap_2','hap_3','hap_4',
               'eco_1','eco_2','eco_3','eco_4','trust_1','trust_2','trust_3',
              'trust_4','health_1','health_2','health_3','health_4'], axis=1)

# %%
pollutes['pollutes']=1

# %%
pollutes.head()
# Out:
#        co2_5        Beef5       Dep5         pop_5  hap_5  eco_5  trust_5  \
# 4    564.033   974.517333  1215983.0  3.741100e+07  7.278  1.365    0.308
# 7   9552.517  8517.757172  4963752.0  1.433784e+09  5.191  1.029    0.100
# 13   568.194   741.288517   808265.0  2.706260e+08  5.192  0.931    0.028
# 14  2392.360  1026.711652  1209803.0  1.366418e+09  4.015  0.755    0.085
# 15   648.061   392.323650   186006.0  8.291400e+07  4.548  1.100    0.125
#
#     health_5  pollutes
# 4      1.039         1
# 7      0.893         1
# 13     0.660         1
# 14     0.588         1
# 15     0.785         1

# %%
no_pollutes=no_pollutes.drop(['co2_1','co2_2','co2_3','co2_4','Beef1','Beef2',
               'Beef3','Beef4','Dep1','Dep2','Dep3','Dep4','pop_1',
               'pop_2','pop_3','pop_4','hap_1','hap_2','hap_3','hap_4',
               'eco_1','eco_2','eco_3','eco_4','trust_1','trust_2','trust_3',
              'trust_4','health_1','health_2','health_3','health_4'], axis=1)

# %%
no_pollutes['pollutes']=0

# %%
no_pollutes.head()
# Out:
#      co2_5        Beef5      Dep5        pop_5  hap_5  eco_5  trust_5  \
# 0  190.930  2584.341559  163106.0   44781000.0  6.086  1.092    0.050
# 1  411.032   729.569784  684170.0   25203000.0  7.228  1.372    0.290
# 2   75.857   200.364477   58497.0  163046000.0  4.456  0.562    0.143
# 3  478.443  8000.274932  814301.0  211050000.0  6.300  1.004    0.086
# 5   39.193   177.333654  225755.0    8591000.0  7.480  1.452    0.343
#
#    health_5  pollutes
# 0     0.881         0
# 1     1.036         0
# 2     0.723         0
# 3     0.802         0
# 5     1.052         0

# %%
data_new = pd.concat([pollutes,no_pollutes],  ignore_index=True)

# %%
data_new.head()
# Out:
#       co2_5        Beef5       Dep5         pop_5  hap_5  eco_5  trust_5  \
# 0   564.033   974.517333  1215983.0  3.741100e+07  7.278  1.365    0.308
# 1  9552.517  8517.757172  4963752.0  1.433784e+09  5.191  1.029    0.100
# 2   568.194   741.288517   808265.0  2.706260e+08  5.192  0.931    0.028
# 3  2392.360  1026.711652  1209803.0  1.366418e+09  4.015  0.755    0.085
# 4   648.061   392.323650   186006.0  8.291400e+07  4.548  1.100    0.125
#
#    health_5  pollutes
# 0     1.039         1
# 1     0.893         1
# 2     0.660         1
# 3     0.588         1
# 4     0.785         1

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   co2_5     36 non-null     float64
#  1   Beef5     36 non-null     float64
#  2   Dep5      36 non-null     float64
#  3   pop_5     36 non-null     float64
#  4   hap_5     36 non-null     float64
#  5   eco_5     36 non-null     float64
#  6   trust_5   36 non-null     float64
#  7   health_5  36 non-null     float64
#  8   pollutes  36 non-null     int64
# dtypes: float64(8), int64(1)
# memory usage: 2.7 KB

# %%
data_new.to_csv("Data_CO2.csv", index=False)
