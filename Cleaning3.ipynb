# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.dpi']=200 # highres display

# %%
#raw_data1 = pd.read_csv("emission_data.csv")
raw_data1 = pd.read_csv("owid_co2_data.csv")

# %%
raw_data1.head(-100)
# Out:
#       iso_code      country  year    co2  co2_growth_prct  co2_growth_abs  \
# 0          AFG  Afghanistan  1949  0.015              NaN             NaN
# 1          AFG  Afghanistan  1950  0.084          475.000           0.070
# 2          AFG  Afghanistan  1951  0.092            8.696           0.007
# 3          AFG  Afghanistan  1952  0.092              NaN             NaN
# 4          AFG  Afghanistan  1953  0.106           16.000           0.015
# ...        ...          ...   ...    ...              ...             ...
# 23603      ZWE     Zimbabwe  1915  0.986           16.957           0.143
# 23604      ZWE     Zimbabwe  1916  1.183           20.074           0.198
# 23605      ZWE     Zimbabwe  1917  1.323           11.765           0.139
# 23606      ZWE     Zimbabwe  1918  1.180          -10.803          -0.143
# 23607      ZWE     Zimbabwe  1919  1.227            4.037           0.048
#
#        consumption_co2  trade_co2  trade_co2_share  co2_per_capita  ...  \
# ...

# %%
population_raw = raw_data1.pivot_table(index='year',columns='country', values='population')

# %%
gdp_raw = raw_data1.pivot_table(index='year',columns='country', values='gdp')

# %%
raw_data1 = raw_data1.pivot_table(index='year',columns='country', values='co2')

# %%
raw_data1.head()
# Out:
# country  Afghanistan  Africa  Albania  Algeria  Andorra  Angola  Anguilla  \
# year
# 1750             NaN     NaN      NaN      NaN      NaN     NaN       NaN
# 1751             NaN     NaN      NaN      NaN      NaN     NaN       NaN
# 1752             NaN     NaN      NaN      NaN      NaN     NaN       NaN
# 1753             NaN     NaN      NaN      NaN      NaN     NaN       NaN
# 1754             NaN     NaN      NaN      NaN      NaN     NaN       NaN
#
# country  Antigua and Barbuda  Argentina  Armenia  ...  Uruguay  Uzbekistan  \
# year                                              ...
# 1750                     NaN        NaN      NaN  ...      NaN         NaN
# 1751                     NaN        NaN      NaN  ...      NaN         NaN
# 1752                     NaN        NaN      NaN  ...      NaN         NaN
# 1753                     NaN        NaN      NaN  ...      NaN         NaN
# 1754                     NaN        NaN      NaN  ...      NaN         NaN
#
# ...

# %%
population_raw.head()
# Out:
# country  Afghanistan  Africa  Albania  Algeria  Andorra  Angola  Anguilla  \
# year
# 1750             NaN     NaN      NaN      NaN      NaN     NaN       NaN
# 1760             NaN     NaN      NaN      NaN      NaN     NaN       NaN
# 1770             NaN     NaN      NaN      NaN      NaN     NaN       NaN
# 1780             NaN     NaN      NaN      NaN      NaN     NaN       NaN
# 1790             NaN     NaN      NaN      NaN      NaN     NaN       NaN
#
# country  Antigua and Barbuda  Argentina  Armenia  ...  United States  Uruguay  \
# year                                              ...
# 1750                     NaN        NaN      NaN  ...            NaN      NaN
# 1760                     NaN        NaN      NaN  ...            NaN      NaN
# 1770                     NaN        NaN      NaN  ...            NaN      NaN
# 1780                     NaN        NaN      NaN  ...            NaN      NaN
# ...

# %%
raw_data1=raw_data1.reset_index(level='year')

# %%
raw_data1.head()
# Out:
# country  year  Afghanistan  Africa  Albania  Algeria  Andorra  Angola  \
# 0        1750          NaN     NaN      NaN      NaN      NaN     NaN
# 1        1751          NaN     NaN      NaN      NaN      NaN     NaN
# 2        1752          NaN     NaN      NaN      NaN      NaN     NaN
# 3        1753          NaN     NaN      NaN      NaN      NaN     NaN
# 4        1754          NaN     NaN      NaN      NaN      NaN     NaN
#
# country  Anguilla  Antigua and Barbuda  Argentina  ...  Uruguay  Uzbekistan  \
# 0             NaN                  NaN        NaN  ...      NaN         NaN
# 1             NaN                  NaN        NaN  ...      NaN         NaN
# 2             NaN                  NaN        NaN  ...      NaN         NaN
# 3             NaN                  NaN        NaN  ...      NaN         NaN
# 4             NaN                  NaN        NaN  ...      NaN         NaN
#
# country  Vanuatu  Venezuela  Vietnam  Wallis and Futuna Islands  World  Yemen  \
# ...

# %%
population_raw  = population_raw.reset_index(level='year')

# %%
population_raw.head()
# Out:
# country  year  Afghanistan  Africa  Albania  Algeria  Andorra  Angola  \
# 0        1750          NaN     NaN      NaN      NaN      NaN     NaN
# 1        1760          NaN     NaN      NaN      NaN      NaN     NaN
# 2        1770          NaN     NaN      NaN      NaN      NaN     NaN
# 3        1780          NaN     NaN      NaN      NaN      NaN     NaN
# 4        1790          NaN     NaN      NaN      NaN      NaN     NaN
#
# country  Anguilla  Antigua and Barbuda  Argentina  ...  United States  \
# 0             NaN                  NaN        NaN  ...            NaN
# 1             NaN                  NaN        NaN  ...            NaN
# 2             NaN                  NaN        NaN  ...            NaN
# 3             NaN                  NaN        NaN  ...            NaN
# 4             NaN                  NaN        NaN  ...            NaN
#
# country  Uruguay  Uzbekistan  Vanuatu  Venezuela  Vietnam        World  Yemen  \
# ...

# %%
gdp_raw = gdp_raw.reset_index(level='year')

# %%
gdp_raw.head()
# Out:
# country  year  Afghanistan  Albania  Algeria  Angola  Argentina  Armenia  \
# 0        1820          NaN      NaN      NaN     NaN        NaN      NaN
# 1        1821          NaN      NaN      NaN     NaN        NaN      NaN
# 2        1822          NaN      NaN      NaN     NaN        NaN      NaN
# 3        1823          NaN      NaN      NaN     NaN        NaN      NaN
# 4        1824          NaN      NaN      NaN     NaN        NaN      NaN
#
# country  Australia       Austria  Azerbaijan  ...  United Kingdom  \
# 0              NaN  4.447080e+09         NaN  ...    4.632226e+10
# 1              NaN           NaN         NaN  ...    4.702428e+10
# 2              NaN           NaN         NaN  ...    4.774658e+10
# 3              NaN           NaN         NaN  ...    4.901127e+10
# 4              NaN           NaN         NaN  ...    5.162573e+10
#
# country  United States  Uruguay  Uzbekistan  Venezuela  Vietnam  World  Yemen  \
# ...

# %%
raw_data1_new = raw_data1.loc[:,["year","World"]]

# %%
raw_data1_new.head()
# Out:
# country  year  World
# 0        1750  9.351
# 1        1751  9.351
# 2        1752  9.354
# 3        1753  9.354
# 4        1754  9.358

# %%
population_raw = population_raw.loc[:,["year","World"]]

# %%
population_raw.head()
# Out:
# country  year        World
# 0        1750  811562112.0
# 1        1760          NaN
# 2        1770          NaN
# 3        1780          NaN
# 4        1790          NaN

# %%
gdp_raw  = gdp_raw.loc[:,["year","World"]]

# %%
gdp_raw.head()
# Out:
# country  year  World
# 0        1820    NaN
# 1        1821    NaN
# 2        1822    NaN
# 3        1823    NaN
# 4        1824    NaN

# %%
raw_data1_new = raw_data1_new[raw_data1_new['year']>1969]

# %%
raw_data1_new.head()
# Out:
# country  year      World
# 220      1970  14826.863
# 221      1971  15425.831
# 222      1972  16142.605
# 223      1973  17000.713
# 224      1974  16925.872

# %%
population_raw = population_raw[population_raw['year']>1969]

# %%
population_raw.head()
# Out:
# country  year         World
# 175      1970  3.700437e+09
# 176      1971  3.775760e+09
# 177      1972  3.851651e+09
# 178      1973  3.927781e+09
# 179      1974  4.003794e+09

# %%
gdp_raw = gdp_raw[gdp_raw['year']>1969]

# %%
gdp_raw.head()
# Out:
# country  year         World
# 150      1970  2.184290e+13
# 151      1971  2.284110e+13
# 152      1972  2.398810e+13
# 153      1973  2.569920e+13
# 154      1974  2.673550e+13

# %%
population =population_raw.drop(177)

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 175 to 224
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    49 non-null     int64
#  1   World   49 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB

# %%
CO2 =raw_data1_new.drop(222)

# %%
CO2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 220 to 269
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    49 non-null     int64
#  1   World   49 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB

# %%
gdp =gdp_raw.drop(152)

# %%
gdp.head()
# Out:
# country  year         World
# 150      1970  2.184290e+13
# 151      1971  2.284110e+13
# 153      1973  2.569920e+13
# 154      1974  2.673550e+13
# 155      1975  2.726860e+13

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 150 to 196
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    46 non-null     int64
#  1   World   46 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB

# %%
plt.plot(CO2['year'],CO2['World'])

# %%
CO2['year'].min(), CO2['year'].max()
# Out:
# (1970, 2019)

# %%
raw_data4 = pd.read_excel("API_IS.AIR.DPRT_DS2_en_excel_v2_2448103.xls", sheet_name='Data',  comment='#')

# %%
raw_data4.info(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 65 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  264 non-null    object
#  4   1960            0 non-null      float64
#  5   1961            0 non-null      float64
#  6   1962            0 non-null      float64
#  7   1963            0 non-null      float64
#  8   1964            0 non-null      float64
#  9   1965            0 non-null      float64
#  10  1966            0 non-null      float64
#  11  1967            0 non-null      float64
#  12  1968            0 non-null      float64
#  13  1969            0 non-null      float64
#  14  1970            145 non-null    float64
#  15  1971            147 non-null    float64
#  16  1972            145 non-null    float64
# ...

# %%
list_y = ['1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980'
          ,'1981','1982','1983','1984','1985','1986','1987','1988','1989','1990'
          ,'1991','1992','1993','1994','1995','1996','1997','1998','1999','2000'
          ,'2001','2002','2003','2004','2005','2006','2007','2008','2009','2010'
          ,'2011','2012','2013','2014','2015','2016','2017','2018','2019']

# %%
raw_data4_new = pd.melt(frame=raw_data4, id_vars='Country Name', value_vars=list_y)

# %%
raw_data4_new.head()
# Out:
#   Country Name variable   value
# 0        Aruba     1970     NaN
# 1  Afghanistan     1970  4000.0
# 2       Angola     1970     NaN
# 3      Albania     1970     NaN
# 4      Andorra     1970     NaN

# %%
raw_data4_new = raw_data4_new.dropna()

# %%
raw_data4_new.head()
# Out:
#    Country Name variable     value
# 1   Afghanistan     1970    4000.0
# 5    Arab World     1970  145300.0
# 7     Argentina     1970   71700.0
# 11    Australia     1970  283300.0
# 12      Austria     1970   14900.0

# %%
raw_data4_new = raw_data4_new.pivot_table(index='variable',columns='Country Name', values='value')

# %%
raw_data4_new.head()
# Out:
# Country Name  Afghanistan  Albania  Algeria  American Samoa  Angola  \
# variable
# 1970               4000.0      NaN  14800.0             NaN     NaN
# 1971               4700.0      NaN  17400.0             NaN     NaN
# 1972               4800.0      NaN  19300.0             NaN     NaN
# 1973               3700.0      NaN  26200.0             NaN     NaN
# 1974               4300.0      NaN  29300.0             NaN     NaN
#
# Country Name  Antigua and Barbuda  Arab World  Argentina  Armenia  Aruba  ...  \
# variable                                                                  ...
# 1970                          NaN    145300.0    71700.0      NaN    NaN  ...
# 1971                          NaN    151200.0    75600.0      NaN    NaN  ...
# 1972                          NaN    159800.0    79000.0      NaN    NaN  ...
# 1973                          NaN    173400.0    71100.0      NaN    NaN  ...
# 1974                          NaN    201400.0    79000.0      NaN    NaN  ...
# ...

# %%
raw_data4_new=raw_data4_new.reset_index(level='variable')

# %%
raw_data4_new.head()
# Out:
# Country Name variable  Afghanistan  Albania  Algeria  American Samoa  Angola  \
# 0                1970       4000.0      NaN  14800.0             NaN     NaN
# 1                1971       4700.0      NaN  17400.0             NaN     NaN
# 2                1972       4800.0      NaN  19300.0             NaN     NaN
# 3                1973       3700.0      NaN  26200.0             NaN     NaN
# 4                1974       4300.0      NaN  29300.0             NaN     NaN
#
# Country Name  Antigua and Barbuda  Arab World  Argentina  Armenia  ...  \
# 0                             NaN    145300.0    71700.0      NaN  ...
# 1                             NaN    151200.0    75600.0      NaN  ...
# 2                             NaN    159800.0    79000.0      NaN  ...
# 3                             NaN    173400.0    71100.0      NaN  ...
# 4                             NaN    201400.0    79000.0      NaN  ...
#
# Country Name  Upper middle income  Uruguay  Uzbekistan  Vanuatu  \
# ...

# %%
raw_data4_new2 = raw_data4_new.loc[:,["variable","World"]]

# %%
raw_data4_new2.head()
# Out:
# Country Name variable      World
# 0                1970  9448300.0
# 1                1971  9504500.0
# 2                1972        NaN
# 3                1973  9764900.0
# 4                1974  9254900.0

# %%
raw_data4_new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   variable  50 non-null     object
#  1   World     49 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 928.0+ bytes

# %%
raw_data4_new2 = raw_data4_new2.drop(2)

# %%
flights = pd.DataFrame(raw_data4_new2, dtype=np.int64)

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   variable  49 non-null     int64
#  1   World     49 non-null     int64
# dtypes: int64(2)
# memory usage: 1.1 KB

# %%
plt.plot(flights['variable'],flights['World'])
#plt.yscale('log')

# %%
plt.plot(CO2['year'],CO2['World'])
plt.scatter(CO2['year'],CO2['World'])
plt.xlabel('Year')
plt.ylabel('Global CO2 emission')
# Out:
# Text(0, 0.5, 'Global CO2 emission')

# %%
plt.scatter(population['year'],population['World'])
plt.xlabel('Year')
plt.ylabel('Global population')
plt.yscale('log')

# %%
plt.scatter(gdp['year'],gdp['World'])
plt.xlabel('Year')
plt.ylabel('GDP')
# Out:
# Text(0, 0.5, 'GDP')

# %%
plt.scatter(flights['World']/1.e7, CO2['World'])
plt.xlabel("Global departures per year (x$10^{7}$)")
plt.ylabel(r"Global CO2 emission per year")
#plt.xscale('log')
# Out:
# Text(0, 0.5, 'Global CO2 emission per year')

# %%
############################################
###########Building a new dataset#####
